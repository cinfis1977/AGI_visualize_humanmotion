# %% [markdown]
# # Stage5E — Per-Joint MDN Walking Animation
# ### Google Colab Training
#
# **Setup (tek seferlik):**
# 1. AMASS KIT walking verilerini Google Drive'a koy: `MyDrive/amass_npz/KIT/`
# 2. Bu notebook'u çalıştır — GitHub'dan kodu clone'lar, eğitir, animasyon üretir
#
# **Özellikler:**
# - CUDA GPU (T4/V100) — differentiable FK + full-batch + foot-weighted loss
# - ~100 epoch, 5-10 dakika
# - Animasyon otomatik download

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone repo
# !git clone https://github.com/cinfis1977/AGI_visualize_humanmotion.git
# %cd AGI_visualize_humanmotion/scripts

# Verify
# !ls *.py | head -5
print("Repo cloned. Ready.")

# %%
# Check GPU & install deps (do NOT reinstall torch - Colab has CUDA version)
# !nvidia-smi --query-gpu=name --format=csv,noheader
# !pip install -q numpy matplotlib
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'N/A'}")
print(f"PyTorch: {torch.__version__}")
# If CUDA not available, install CUDA torch
import sys
if not torch.cuda.is_available():
    # !pip install -q torch --index-url https://download.pytorch.org/whl/cu121
    import torch
    print(f"Reinstalled torch. CUDA now: {torch.cuda.is_available()}")

# %%
# Train! Subject 675 — 119 walks (proven working)
# !python stage5e_colab.py \
  --data-dir /content/drive/MyDrive/amass_npz/KIT \
  --subject 675 \
  --epochs 100 \
  --batch-size 32 \
  --animate \
  --scale 1.30

# %%
# Download animation (stage5e_colab_100ep.gif)
from google.colab import files
import glob
gifs = sorted(glob.glob("stage5e_colab_*.gif"))
if gifs:
    print(f"Found: {gifs}")
    files.download(gifs[-1])
else:
    print("No animation found. Did training complete?")
