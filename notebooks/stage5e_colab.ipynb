# %% [markdown]
# # Stage5E — Per-Joint MDN Walking Animation
# ### Google Colab Training
#
# 1. Mount Google Drive (AMASS data must be in Drive)
# 2. Clone GitHub repo
# 3. Train with differentiable FK + foot-weighted loss

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone repo
# !git clone https://github.com/YOUR_USERNAME/visualAGI-goalkeeper-trajectory.git
# %cd visualAGI-goalkeeper-trajectory/scripts

# %%
# Install deps
# !pip install torch numpy matplotlib

# %%
# Train! (adjust --data-dir to your Drive path)
# --subject 675 for single-subject (119 walks)
# --subject 9 for another subject (70 walks)
# omit --subject for multi-subject
# !python stage5e_colab.py \
  --data-dir /content/drive/MyDrive/amass_npz/KIT \
  --subject 675 \
  --epochs 100 \
  --batch-size 32 \
  --animate \
  --scale 1.30

# %%
# Download animation
from google.colab import files
files.download('stage5e_colab_100ep.gif')
